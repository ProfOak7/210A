# %%
# importing the required module 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Optional for disabling warnings 
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
#Set figure resolution to 300dpi
import matplotlib as mpl
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
df = pd.read_excel (r'/Users/jonathanokerblom/Dropbox/My Mac (Jonathan’s MacBook Air)/Documents/210A_Exam_2.xlsx', index_col=0) 
df.describe()
# Out:
#            Score  Unnamed: 3  Unnamed: 4     Curved    percent  percent_curved
# count  44.000000   44.000000   44.000000  43.000000  43.000000       43.000000
# mean   15.000000    0.576923    0.786891  12.000046  57.692308       80.000308
# std     4.569871    0.175764    0.196106   2.667666  17.784439       17.784439
# min     7.000000    0.269231    0.223077   7.384662  26.923077       49.231077
# 25%    11.000000    0.423077    0.646157   9.692354  42.307692       64.615692
# 50%    15.000000    0.576923    0.800003  12.000046  57.692308       80.000308
# 75%    18.000000    0.692308    0.915388  13.730815  69.230769       91.538769
# max    24.000000    0.923077    1.146157  17.192354  92.307692      114.615692

# %%
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram on x
x1 = df.percent
plt.hist(x1, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Original Score', ylabel='Frequency');
plt.xlim(0,120)

plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x.mean()))
# Out:
# Text(63.46153846153846, 5.67, 'Mean: 57.69')

# %%
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram on x
x2 = df.percent_curved
plt.hist(x2, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Curved Score', ylabel='Frequency');
plt.xlim(0,120)

plt.axvline(x2.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()))
# Out:
# Text(88.00033846153846, 5.67, 'Mean: 80.00')

# %%
kwargs = dict(hist_kws={'alpha':.4}, kde_kws={'linewidth':3})

plt.figure(figsize=(10,7), dpi= 300)
sns.distplot(x1, bins = 25, color="dodgerblue", label="Original", **kwargs)
plt.axvline(x1.mean(), color='dodgerblue', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()), color="dodgerblue")

sns.distplot(x2, bins = 25, color="orange", label="Curved", **kwargs)
plt.axvline(x2.mean(), color='orange', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()), color="orange")
plt.xlim(0,120)
plt.legend();
plt.gca().set(title='210A Spring 2022 - Exam 2 Scores - Before and After Curve', ylabel='Density', xlabel='Score');
